# %% [markdown]
# # Optimización de Parámetros - Regresión Lineal

# %%
## Get current work directory to load all the custom modules
from pathlib import Path
import os
import sys
BASE_DIR = Path().absolute().resolve(strict=True).parent.parent.parent
if str(BASE_DIR) not in sys.path:
    sys.path.append(str(BASE_DIR))

# %%
DATA_PATH = os.path.join(BASE_DIR, 'data', 'autos')
print(DATA_PATH)
# Out:
# /workspace/Externos/TimeSeries/BenchMark/data/autos

# %%
import pandas as pd

# %%
import optuna
import datetime

# %%
from modulos.arima.gruas.general import format_timeseries, show_results_r2, arima_forecasting, total_forecasting, show_optimizer_results
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

from modulos.LR.gruas.generals import make_lags
from modulos.LR.gruas.optimizer import LROptimizer

# %%
data = pd.read_csv(os.path.join(DATA_PATH, 'producto.csv'), parse_dates=['Periodo'])
data.head()
# Out:
#      Periodo  idArticulo  ventas  \
# 0 2021-05-01        9950    37.0
# 1 2021-04-01        9950    19.0
# 2 2021-03-01        9950     9.0
# 3 2021-02-01        9950     8.0
# 4 2021-01-01        9950    76.0
#
#                                         DescProducto
# 0  REFRIGERANTE COOLANT AZUL/NATURAL TRANSP. GALO...
# 1  REFRIGERANTE COOLANT AZUL/NATURAL TRANSP. GALO...
# 2  REFRIGERANTE COOLANT AZUL/NATURAL TRANSP. GALO...
# 3  REFRIGERANTE COOLANT AZUL/NATURAL TRANSP. GALO...
# 4  REFRIGERANTE COOLANT AZUL/NATURAL TRANSP. GALO...

# %%
# Pivotando las tablas y llenando de ceros las ventas que no existen.
df_time = format_timeseries(data)
df_time.tail()
# Out:
# idArticulo  551    594    1208   1224   1627   3745   3882   3883   4070   \
# Periodo
# 2021-01-01    6.0    3.0  170.0    2.0   10.0    6.0    3.0    4.0    7.0
# 2021-02-01    4.0    4.0  220.0    0.0   17.0   11.0    3.0    3.0    5.0
# 2021-03-01    4.0    6.0  155.0    0.0    8.0   10.0    2.0    0.0    4.0
# 2021-04-01    8.0    8.0  155.0    6.0   25.0   24.0    3.0    9.0    0.0
# 2021-05-01   13.0    4.0   80.0    1.0    5.0    4.0    0.0    4.0    0.0
#
# idArticulo  4827   ...  20301  20305  20309  20310  20697  20769  21577  \
# Periodo            ...
# 2021-01-01   18.0  ...    8.0    4.0    1.0    2.0    0.0    5.0    7.0
# 2021-02-01   16.0  ...    4.0    1.0    1.0   11.0    2.0    1.0   11.0
# 2021-03-01    2.0  ...   14.0   11.0   11.0    9.0    2.0   12.0   13.0
# 2021-04-01    1.0  ...   11.0    4.0    1.0    3.0    1.0    3.0    0.0
# 2021-05-01    1.0  ...   15.0    9.0    9.0    4.0    1.0    1.0   16.0
#
# idArticulo  23900  26158  26170
# Periodo
# 2021-01-01  260.0   16.0    5.0
# 2021-02-01   16.0    5.0   18.0
# 2021-03-01   80.0    6.0   14.0
# 2021-04-01   71.0   10.0    5.0
# 2021-05-01   41.0    3.0    0.0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Optimizando un solo Producto

# %% [markdown]
# ## Baseline LR

# %%
idArticulo = 4827
ts = df_time[idArticulo].copy()

# Lag features
n_lags = 3
X = make_lags(ts, n_lags)
# Multistep targets
y = pd.DataFrame({
    'y': ts,
})

y, X = y.align(X, join='inner', axis=0)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_fit = pd.DataFrame(model.predict(X), index=X.index, columns=y.columns)
#y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index, columns=y.columns)

# %%
show_results_r2(df_time, y_fit, idArticulo)
# Out:
# 0.024689739216515627

# %% [markdown]
# # Optimizar todos los Productos

# %%
optimizer = LROptimizer(df_time, iterations=7, data_path= DATA_PATH , model='LR')
optimizer.run( chunk_size=4)

# %%
optimizer.print_results()

# %% [markdown]
# # Optimizer -  Evolution on time

# %%
optimizer.print_optimizer_results()

# %%
optimizer.results
# Out:
#     idArticulo          hyper         r2 model
# 0       1208.0  {'n_lags': 1}  -4.379924    LR
# 1       1224.0  {'n_lags': 1}  -0.320980    LR
# 2        551.0  {'n_lags': 1}  -3.053403    LR
# 3        594.0  {'n_lags': 1}  -0.554180    LR
# 4       3883.0  {'n_lags': 1}  -1.063148    LR
# 5       3745.0  {'n_lags': 1}  -2.468204    LR
# 6       3882.0  {'n_lags': 1}  -2.424972    LR
# 7       5579.0  {'n_lags': 1} -28.201562    LR
# 8       5389.0  {'n_lags': 6}  -5.296826    LR
# 9       4827.0  {'n_lags': 1}  -0.352009    LR
# 10      4070.0  {'n_lags': 1}  -2.241428    LR
# 11      6833.0  {'n_lags': 2}  -2.181160    LR
# 12      7799.0  {'n_lags': 3}  -1.887145    LR
# 13      7798.0  {'n_lags': 2}  -2.959346    LR
# 14      7801.0  {'n_lags': 6}  -0.894190    LR
# 15      9950.0  {'n_lags': 1}  -0.949721    LR
# 16     10702.0  {'n_lags': 3}  -3.943232    LR
# 17      9776.0  {'n_lags': 6}  -1.401532    LR
# 18     10927.0  {'n_lags': 1}  -8.337083    LR
# 19     10960.0  {'n_lags': 1}  -3.762256    LR
# 20     11397.0  {'n_lags': 6}  -6.799736    LR
# 21     11395.0  {'n_lags': 1}  -1.785224    LR
# 22     10964.0  {'n_lags': 1}  -1.795942    LR
# 23     11523.0  {'n_lags': 1}  -2.001329    LR
# 24     11509.0  {'n_lags': 2}  -5.602939    LR
# 25     11807.0  {'n_lags': 6}  -4.142114    LR
# 26     14606.0  {'n_lags': 1}  -1.850487    LR
# 27     14708.0  {'n_lags': 1}  -4.282316    LR
# 28     14709.0  {'n_lags': 2}  -6.488429    LR
# 29     17413.0  {'n_lags': 1}  -1.645822    LR
# 30     16404.0  {'n_lags': 1}  -1.706135    LR
# 31     17804.0  {'n_lags': 1}  -1.472526    LR
# 32     17779.0  {'n_lags': 1}  -3.176900    LR
# 33     17750.0  {'n_lags': 1}  -1.790871    LR
# 34     17414.0  {'n_lags': 1}  -0.667752    LR
# 35     20301.0  {'n_lags': 1}  -1.027273    LR
# 36     19574.0  {'n_lags': 1}  -0.617324    LR
# 37     19571.0  {'n_lags': 6}  -0.971652    LR
# 38     20263.0  {'n_lags': 1}  -3.069928    LR
# 39     20697.0  {'n_lags': 1}  -2.157548    LR
# 40     20305.0  {'n_lags': 6}  -2.806279    LR
# 41     20310.0  {'n_lags': 6}  -1.762313    LR
# 42     20309.0  {'n_lags': 1}  -2.297492    LR
# 43     21577.0  {'n_lags': 1}  -1.286866    LR
# 44     20769.0  {'n_lags': 6}  -1.134071    LR
# 45     26158.0  {'n_lags': 2}  -2.123491    LR
# 46     23900.0  {'n_lags': 6}  -2.902472    LR
# 47     26170.0  {'n_lags': 1}  -0.570590    LR
